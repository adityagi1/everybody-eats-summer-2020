# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datapath = "../Data/FA_PM/fa_pm_merged_data.csv"
fa_pm = pd.read_csv(datapath)
fa_pm['food_insecurity_num_2018'] = fa_pm['food_insecurity_num_2018'].apply(lambda x: int(x.replace(',','')))
fa_pm['food_insecurity_num_2020'] = fa_pm['food_insecurity_num_2020'].apply(lambda x: int(x.replace(',','')))
#fa_pm.drop(['Unnamed: 0'], axis = 1, inplace = True)
fa_pm.head()
# Out:
#                                       Tract   fips state total_population  \
# 0  Census Tract 1001, Cook County, Illinois  17031    IL            5,563
# 1  Census Tract 1002, Cook County, Illinois  17031    IL            6,872
# 2  Census Tract 1003, Cook County, Illinois  17031    IL            6,186
# 3  Census Tract 1004, Cook County, Illinois  17031    IL            3,364
# 4  Census Tract 1005, Cook County, Illinois  17031    IL            5,696
#
#    food_insecurity_rate_2018  food_insecurity_num_2018  \
# 0                      0.099                       550
# 1                      0.060                       410
# 2                      0.074                       460
# 3                      0.055                       180
# 4                      0.052                       290
#
#    food_insecurity_rate_2020  food_insecurity_num_2020  \
# 0                      0.149                       820
# 1                      0.110                       750
# 2                      0.123                       770
# 3                      0.104                       350
# 4                      0.101                       570
#
#    food_insecurity_num_change_2020  unemployment_change  ...  \
# 0                              270                 0.07  ...
# 1                              340                 0.07  ...
# 2                              310                 0.07  ...
# 3                              170                 0.07  ...
# 4                              280                 0.07  ...
#
#    proportion_bachelors_degree  proportion_disabled  proportion_hispanic  \
# 0                        26.32                10.84                16.07
# 1                        22.21                 6.48                11.04
# 2                        25.82                17.10                10.17
# 3                        28.45                 8.98                13.97
# 4                        25.93                12.90                10.45
#
#    prop_men  prop_nonwhite  prop_nonenglish_speaking  prop_families_poverty  \
# 0     48.30           4.31                     12.54                   6.60
# 1     47.22          10.84                      5.79                  11.35
# 2     44.94          11.75                      7.64                   2.00
# 3     51.25           7.52                      3.97                   0.93
# 4     47.82          12.34                     14.19                   0.00
#
#    prop_students_in_public_school  social_vulnerability_index  \
# 0                           53.92                        0.36
# 1                           79.56                        0.34
# 2                           68.25                        0.30
# 3                           68.16                        0.27
# 4                           68.67                        0.28
#
#    thiel_racial_segregation_index
# 0                            0.24
# 1                            0.20
# 2                            0.22
# 3                            0.15
# 4                            0.20
#
# [5 rows x 32 columns]

# %%
print(fa_pm.shape)
print(fa_pm.columns)
# Out:
# (1319, 32)
# Index(['Tract', 'fips', 'state', 'total_population',
#        'food_insecurity_rate_2018', 'food_insecurity_num_2018',
#        'food_insecurity_rate_2020', 'food_insecurity_num_2020',
#        'food_insecurity_num_change_2020', 'unemployment_change',
#        'local_census_tract', 'avg_household_size', 'avg_travel_time_to_work',
#        'computer_access', 'life_expectancy', 'median_age',
#        'median_home_loan_amount', 'median_home_value',
#        'median_household_income', 'median_leverage_ratio', 'num_jobs',
#        'num_housing_units', 'proportion_bachelors_degree',
#        'proportion_disabled', 'proportion_hispanic', 'prop_men',
#        'prop_nonwhite', 'prop_nonenglish_speaking', 'prop_families_poverty',
#        'prop_students_in_public_school', 'social_vulnerability_index',
#        'thiel_racial_segregation_index'],
#       dtype='object')

# %%
modelling_cols = [
       'avg_household_size', 'avg_travel_time_to_work', 'computer_access',
       'life_expectancy', 'median_age', 'median_home_loan_amount',
       'median_home_value', 'median_household_income', 'median_leverage_ratio',
       'num_jobs', 'num_housing_units', 'proportion_bachelors_degree',
       'proportion_disabled', 'proportion_hispanic', 'prop_men',
       'prop_nonwhite', 'prop_nonenglish_speaking', 'prop_families_poverty',
       'prop_students_in_public_school', 'social_vulnerability_index',
       'thiel_racial_segregation_index']
fa_pm[modelling_cols].hist(bins = 30, figsize = (17,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015097185100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015096D20C70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015096E2A400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015096D50280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000150973D9040>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000150973CCA00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015096F4C5E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001509706FD00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015096FD43A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015097091160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015097366820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015097386B80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000150972BC400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000150973E1C10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001509740C490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000150973AECD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001509725A580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000150972812B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000150972F3610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001509731DE50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001509722C370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015097422D00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015097422F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015097458910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015097480FD0>]],
#       dtype=object)

# %% [markdown]
# From the above plots, we can gain the following insights:
# - average household size has a bell-shaped distribution, with the avg. household size in cook county being 2.5
# - average travel time to work has a bell-shaped distribution, with avg = 35 mins, but there is a massive peak around 37mins.
# - computer access is left-skewed.
# - life expectancy is also left-skewed
# - median_age has a step pattern, but is centered, and has a rough bell shape
# - home loan amount is right skewed
# - home value is right skewed
# - household income is right skewed
# - leverage ratio is centered, and well-distributed
# - num housing units is right skewed
# - num jobs has a massive peak at 0 (almost all the mass). this might not make a good predictor.
# - prop_families poverty is right skewed with a nice stepwise pattern
# - prop_men is well-centered, and has a bellshaped distribution
# - prop_nonenglish speaking is right skewed (interestingly the pattern follows very closely the prop_hispanic)
# - prop_nonwhite follows an S-pattern, with some tracts being entirely nonwhite! (~100%)
# - prop in public school is heavily left skewed
# - prop_bachelor's degree is right skewed
# - proportion disabled is centered, and bellshaped
# - prop_hispanic is highly right-skewed
# - social_vulnerability follows a funny pattern with several peaks
# - racial_segregration is bell-shaped and centered (maybe a slight right skew)

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.heatmap(fa_pm[modelling_cols].corr(), ax = ax)

# %%
for col in modelling_cols:
    print(col)
    sorted_corr = fa_pm[modelling_cols].corr()[col].apply(lambda x: abs(x)).sort_values(ascending = False)
    orig_corr = fa_pm[modelling_cols].corr()[col]
    top_n = sorted_corr.index[1:6]
    for other_col in top_n:
        print(other_col, orig_corr.loc[other_col])
    print('-------')
# Out:
# avg_household_size
# proportion_hispanic 0.5973057962058136
# proportion_bachelors_degree -0.5577041839140697
# prop_nonenglish_speaking 0.47518413987921093
# prop_students_in_public_school 0.3855859425685631
# median_leverage_ratio 0.3791131971576891
# -------
# avg_travel_time_to_work
# life_expectancy -0.2400322833141025
# prop_families_poverty 0.21590216511698468
# computer_access -0.1898271928333366
# prop_nonwhite 0.15566123727754894
# num_jobs -0.15165386109150172
# -------
# computer_access
# social_vulnerability_index -0.7104125587374268
# median_household_income 0.6895394949059441
# prop_families_poverty -0.6805617055191215
# proportion_bachelors_degree 0.6669443477788628
# life_expectancy 0.5929226108295246
# -------
# life_expectancy
# prop_nonwhite -0.7114356239248643
# prop_families_poverty -0.6555033157999018
# median_household_income 0.6430039140058058
# social_vulnerability_index -0.6068846770238433
# computer_access 0.5929226108295246
# -------
# median_age
# prop_families_poverty -0.38511814789376464
# proportion_hispanic -0.3727533759369571
# proportion_disabled 0.34739101520820576
# social_vulnerability_index -0.2784967150987018
# avg_household_size -0.2733457411855457
# -------
# median_home_loan_amount
# median_home_value 0.9086055451093372
# median_household_income 0.7125765227301171
# proportion_bachelors_degree 0.6907366255424964
# social_vulnerability_index -0.6022699959093812
# prop_nonwhite -0.5068915292259941
# -------
# median_home_value
# median_home_loan_amount 0.9086055451093372
# median_household_income 0.8085427042758477
# proportion_bachelors_degree 0.7444250788597502
# social_vulnerability_index -0.6736433051620414
# life_expectancy 0.5662674819518378
# -------
# median_household_income
# social_vulnerability_index -0.8298377806907953
# median_home_value 0.8085427042758477
# proportion_bachelors_degree 0.7245659825912838
# median_home_loan_amount 0.7125765227301171
# computer_access 0.6895394949059441
# -------
# median_leverage_ratio
# proportion_hispanic 0.4277174662312901
# prop_nonenglish_speaking 0.4042268659484516
# avg_household_size 0.3791131971576891
# median_age -0.21793703129538594
# proportion_bachelors_degree -0.2157415309709098
# -------
# num_jobs
# num_housing_units 0.22104361353317475
# life_expectancy 0.18760406374634042
# avg_travel_time_to_work -0.15165386109150172
# avg_household_size -0.13219509686484365
# proportion_bachelors_degree 0.10949699721127314
# -------
# num_housing_units
# avg_household_size -0.29362322421896625
# prop_families_poverty -0.26822688139618006
# computer_access 0.25959538098616125
# life_expectancy 0.2571012579373947
# proportion_bachelors_degree 0.23676219977154347
# -------
# proportion_bachelors_degree
# social_vulnerability_index -0.8027687713577059
# median_home_value 0.7444250788597502
# median_household_income 0.7245659825912838
# median_home_loan_amount 0.6907366255424964
# computer_access 0.6669443477788628
# -------
# proportion_disabled
# computer_access -0.5527363640493714
# prop_nonwhite 0.5400046001223392
# median_household_income -0.5179124812939947
# social_vulnerability_index 0.5047962612017377
# life_expectancy -0.5039241504888412
# -------
# proportion_hispanic
# prop_nonenglish_speaking 0.7966734892581188
# avg_household_size 0.5973057962058136
# median_leverage_ratio 0.4277174662312901
# proportion_bachelors_degree -0.3743750323239182
# median_age -0.3727533759369571
# -------
# prop_men
# prop_nonwhite -0.35723001076268707
# proportion_disabled -0.3226574831540137
# prop_nonenglish_speaking 0.31725005953677754
# proportion_hispanic 0.30372416767535376
# life_expectancy 0.29570297995041517
# -------
# prop_nonwhite
# life_expectancy -0.7114356239248643
# social_vulnerability_index 0.6803153998502033
# prop_families_poverty 0.6709530883285494
# median_household_income -0.654472454142835
# proportion_bachelors_degree -0.5974764858587102
# -------
# prop_nonenglish_speaking
# proportion_hispanic 0.7966734892581188
# avg_household_size 0.47518413987921093
# median_leverage_ratio 0.4042268659484516
# prop_men 0.31725005953677754
# social_vulnerability_index 0.31428681620523
# -------
# prop_families_poverty
# social_vulnerability_index 0.7411464949566523
# median_household_income -0.6871149367395364
# computer_access -0.6805617055191215
# prop_nonwhite 0.6709530883285494
# life_expectancy -0.6555033157999018
# -------
# prop_students_in_public_school
# proportion_bachelors_degree -0.5237409340759662
# social_vulnerability_index 0.4916011190860241
# median_household_income -0.43980261521429054
# median_home_value -0.43477932497195654
# median_home_loan_amount -0.3917974415430704
# -------
# social_vulnerability_index
# median_household_income -0.8298377806907953
# proportion_bachelors_degree -0.8027687713577059
# prop_families_poverty 0.7411464949566523
# computer_access -0.7104125587374268
# prop_nonwhite 0.6803153998502033
# -------
# thiel_racial_segregation_index
# prop_nonwhite 0.4442468735440445
# proportion_bachelors_degree -0.41525339413276985
# life_expectancy -0.4108270069008947
# computer_access -0.40036686725525844
# proportion_disabled 0.3762056531973892
# -------

# %% [markdown]
# The following correlations are worthy of notice:
# - avg household size is positively correlated (>0.6) with proportion hispanic, negatively with proportion bachelors degree, positively with prop nonenglish speaking
# - computer access is negatively correlated (<-0.7) with social_vulnerability, positively with median_household income, negatively with prop_families_poverty, positively with prop_bachelor's degree, positively with life_expectancy
# - life_expectancy is negatively corr with prop_nonwhite, negatively with prop_families_poverty, positively with household_income, negatively with social vulnerability, and positively with computer access
# - home_loan_amount is strongly positively associated with home_value, household_income, prop_bachelor's degree, negatively with social_vulnerability.
# - median_home_value is positively associated with prop_bachelors_degree, and negatively with social vulnerability
# - household_income negatively correlated with social_vulnerability
# - prop_disabled is negatively corr with computer_access, positively corr with prop_nonwhite
# - prop_hispanic is strong positively corr with prop_nonenglish speaking, household_size
# - prop_nonwhite is negatively corr with life_expectancy, positively with social vulnerabilty, and poverty

# %%
# Find out the variables with the highest correlations with the food insecurity rate in 2020
corr_df = fa_pm.corr()
corr_df1 = corr_df['food_insecurity_rate_2020'][abs(corr_df['food_insecurity_rate_2020'])>=0.5]
corr_df1
# Out:
# food_insecurity_rate_2018      0.999986
# food_insecurity_num_2018       0.593259
# food_insecurity_rate_2020      1.000000
# computer_access               -0.696281
# life_expectancy               -0.761816
# median_home_value             -0.517237
# median_household_income       -0.715284
# proportion_bachelors_degree   -0.561098
# proportion_disabled            0.617030
# prop_nonwhite                  0.809974
# prop_families_poverty          0.851427
# social_vulnerability_index     0.719897
# Name: food_insecurity_rate_2020, dtype: float64

# %% [markdown]
# The following variables are strongly positively associated with food insecurity:
# - prop_disabled
# - prop_nonwhite
# - prop_families in poverty
# - social vulnerability index
#
# The following variables are strongly negatively associated with food insecurity:
# - computer access
# - life expectancy
# - median home value
# - median household income
# - prop bachelor's degree

# %%
#find variables strongly associated with food_insecurity_num_2020
corr_df2 = corr_df['food_insecurity_num_2020'].sort_values(ascending= False)
corr_df2
# Out:
# food_insecurity_num_2020           1.000000e+00
# food_insecurity_num_2018           9.732618e-01
# food_insecurity_num_change_2020    6.049230e-01
# num_housing_units                  5.388670e-01
# social_vulnerability_index         4.909845e-01
# food_insecurity_rate_2018          4.281980e-01
# food_insecurity_rate_2020          4.281146e-01
# prop_nonwhite                      4.024028e-01
# prop_families_poverty              3.805584e-01
# proportion_disabled                2.684108e-01
# prop_students_in_public_school     2.520572e-01
# avg_travel_time_to_work            1.736252e-01
# thiel_racial_segregation_index     1.584622e-01
# avg_household_size                 1.333590e-01
# local_census_tract                 7.511888e-02
# num_jobs                           4.163496e-02
# prop_nonenglish_speaking           3.118388e-02
# unemployment_change               -5.158455e-16
# proportion_hispanic               -8.058247e-04
# median_leverage_ratio             -8.972743e-03
# median_age                        -1.349264e-01
# prop_men                          -1.385310e-01
# computer_access                   -2.709141e-01
# life_expectancy                   -3.045133e-01
# proportion_bachelors_degree       -3.775700e-01
# median_home_value                 -4.082339e-01
# median_home_loan_amount           -4.094018e-01
# median_household_income           -4.245279e-01
# fips                                        NaN
# Name: food_insecurity_num_2020, dtype: float64

# %% [markdown]
# the following should be used as a modelling variables:
# - food_insecurity_num_2018 (0.97)
# - num_housing_units (0.5388)
# - social_vulnerability_index (0.49)
# - median_household_income (-0.4245)
# - prop_nonwhite (0.4024)
# - median_home_value (-0.408)
# - median_home_loan_amount (-0.409)
# - prop_families_poverty (0.381)
# - proportion_bachelors_degree (-0.3775)
# - life_expectancy (-0.3045)
#
#
# the following may be optionally added
# - prop_disabled (0.268)
# - prop_students_in_public_school (0.252)
# - avg_travel_time_to_work (0.173)
# - thiel_racial_segregation_index (0.158)
# - avg_household_size (0.133)
# - median_age (-0.135)
# - prop_men (-0.138)

# %%
#find center, spread for each variable
for col in modelling_cols:
    print(col)
    print("        min:", fa_pm[col].min())
    print("        mean:", fa_pm[col].mean())
    print("        median:", fa_pm[col].median())
    print("        max:", fa_pm[col].max())
    print("        std. dev.:", fa_pm[col].std())
    print("----------")

# %%
modelling_set = ['food_insecurity_num_2018', 'num_housing_units', 'social_vulnerability_index',
'median_household_income', 'prop_nonwhite', 'median_home_value', 'median_home_loan_amount', 'prop_families_poverty',
'proportion_bachelors_degree', 'life_expectancy']
fa_pm[modelling_set].drop('food_insecurity_num_2018', axis = 1).corr()
# Out:
#                              num_housing_units  social_vulnerability_index  \
# num_housing_units                     1.000000                   -0.195398
# social_vulnerability_index           -0.195398                    1.000000
# median_household_income               0.154315                   -0.829838
# prop_nonwhite                        -0.218887                    0.680315
# median_home_value                     0.067181                   -0.673643
# median_home_loan_amount              -0.003795                   -0.602270
# prop_families_poverty                -0.268227                    0.741146
# proportion_bachelors_degree           0.236762                   -0.802769
# life_expectancy                       0.257101                   -0.606885
#
#                              median_household_income  prop_nonwhite  \
# num_housing_units                           0.154315      -0.218887
# social_vulnerability_index                 -0.829838       0.680315
# median_household_income                     1.000000      -0.654472
# prop_nonwhite                              -0.654472       1.000000
# median_home_value                           0.808543      -0.565244
# median_home_loan_amount                     0.712577      -0.506892
# prop_families_poverty                      -0.687115       0.670953
# proportion_bachelors_degree                 0.724566      -0.597476
# life_expectancy                             0.643004      -0.711436
#
#                              median_home_value  median_home_loan_amount  \
# num_housing_units                     0.067181                -0.003795
# social_vulnerability_index           -0.673643                -0.602270
# median_household_income               0.808543                 0.712577
# prop_nonwhite                        -0.565244                -0.506892
# median_home_value                     1.000000                 0.908606
# median_home_loan_amount               0.908606                 1.000000
# prop_families_poverty                -0.483852                -0.410100
# proportion_bachelors_degree           0.744425                 0.690737
# life_expectancy                       0.566267                 0.481578
#
#                              prop_families_poverty  \
# num_housing_units                        -0.268227
# social_vulnerability_index                0.741146
# median_household_income                  -0.687115
# prop_nonwhite                             0.670953
# median_home_value                        -0.483852
# median_home_loan_amount                  -0.410100
# prop_families_poverty                     1.000000
# proportion_bachelors_degree              -0.600765
# life_expectancy                          -0.655503
#
#                              proportion_bachelors_degree  life_expectancy
# num_housing_units                               0.236762         0.257101
# social_vulnerability_index                     -0.802769        -0.606885
# median_household_income                         0.724566         0.643004
# prop_nonwhite                                  -0.597476        -0.711436
# median_home_value                               0.744425         0.566267
# median_home_loan_amount                         0.690737         0.481578
# prop_families_poverty                          -0.600765        -0.655503
# proportion_bachelors_degree                     1.000000         0.580121
# life_expectancy                                 0.580121         1.000000

# %%
#### NOW ANALYZE EVANSTON ONLY
pd.read_csv("../Data/Modelling Data/fa_pm_evanston-model.csv")
"""
for col in modelling_cols:
    print(col)
    sorted_corr = fa_pm[modelling_cols].corr()[col].apply(lambda x: abs(x)).sort_values(ascending = False)
    orig_corr = fa_pm[modelling_cols].corr()[col]
    top_n = sorted_corr.index[1:6]
    for other_col in top_n:
        print(other_col, orig_corr.loc[other_col])
    print('-------')   
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7accb821a22f> in <module>
#       1 #### NOW ANALYZE EVANSTON ONLY
#       2 pd.read_csv("../Data/Modelling Data/fa_pm_evanston-model.csv")
# ----> 3 for col in modelling_cols:
#       4     print(col)
#       5     sorted_corr = fa_pm[modelling_cols].corr()[col].apply(lambda x: abs(x)).sort_values(ascending = False)
#
# NameError: name 'modelling_cols' is not defined

# %%
int('1,490')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-8ece6b883346> in <module>
# ----> 1 int('1,490')
#
# ValueError: invalid literal for int() with base 10: '1,490'
