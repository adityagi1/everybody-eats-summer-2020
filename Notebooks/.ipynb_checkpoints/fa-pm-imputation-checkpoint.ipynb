# %%
import pandas as pd
import numpy as np

# %%
DATAPATH = "../Data/FA_PM/fa_pm_merged_data.csv"
fa_pm = pd.read_csv(DATAPATH)
fa_pm.drop(['Unnamed: 0'], axis = 1, inplace= True)
fa_pm.head()
# Out:
#                                       Tract   FIPS State Total Population  \
# 0  Census Tract 1001, Cook County, Illinois  17031    IL            5,563
# 1  Census Tract 1002, Cook County, Illinois  17031    IL            6,872
# 2  Census Tract 1003, Cook County, Illinois  17031    IL            6,186
# 3  Census Tract 1004, Cook County, Illinois  17031    IL            3,364
# 4  Census Tract 1005, Cook County, Illinois  17031    IL            5,696
#
#    2018 Food Insecurity 2018 Food Insecurity #  [C] 2020 Food Insecurity  \
# 0                 0.099                    550                     0.149
# 1                 0.060                    410                     0.110
# 2                 0.074                    460                     0.123
# 3                 0.055                    180                     0.104
# 4                 0.052                    290                     0.101
#
#   [C] 2020 Food Insecurity #  [C] 2020 Food Insecurity # Change  \
# 0                        820                                270
# 1                        750                                340
# 2                        770                                310
# 3                        350                                170
# 4                        570                                280
#
#    [C] Adjusted Annual Unemployment Change  ...  proportion_bachelors_degree  \
# 0                                     0.07  ...                        26.32
# 1                                     0.07  ...                        22.21
# 2                                     0.07  ...                        25.82
# 3                                     0.07  ...                        28.45
# 4                                     0.07  ...                        25.93
#
#    proportion_disabled  proportion_hispanic  prop_men  prop_nonwhite  \
# 0                10.84                16.07     48.30           4.31
# 1                 6.48                11.04     47.22          10.84
# 2                17.10                10.17     44.94          11.75
# 3                 8.98                13.97     51.25           7.52
# 4                12.90                10.45     47.82          12.34
#
#    prop_nonenglish_speaking  prop_families_poverty  \
# 0                     12.54                   6.60
# 1                      5.79                  11.35
# 2                      7.64                   2.00
# 3                      3.97                   0.93
# 4                     14.19                   0.00
#
#    prop_students_in_public_school  social_vulnerability_index  \
# 0                           53.92                        0.36
# 1                           79.56                        0.34
# 2                           68.25                        0.30
# 3                           68.16                        0.27
# 4                           68.67                        0.28
#
#    thiel_racial_segregation_index
# 0                            0.24
# 1                            0.20
# 2                            0.22
# 3                            0.15
# 4                            0.20
#
# [5 rows x 32 columns]

# %%
fa_pm.shape
# Out:
# (1319, 32)

# %%
print(fa_pm.isnull().sum())
# Out:
# Tract                                        0
# FIPS                                         0
# State                                        0
# Total Population                             0
# 2018 Food Insecurity                         0
# 2018 Food Insecurity #                       0
# [C] 2020 Food Insecurity                     0
# [C] 2020 Food Insecurity #                   0
# [C] 2020 Food Insecurity # Change            0
# [C] Adjusted Annual Unemployment Change      0
# local_census_tract                           0
# avg_household_size                           9
# avg_travel_time_to_work                    422
# computer_access                              9
# life_expectancy                            123
# median_age                                   9
# median_home_loan_amount                     17
# median_home_value                           22
# median_household_income                      9
# median_leverage_ratio                       17
# num_jobs                                     7
# num_housing_units                            5
# proportion_bachelors_degree                  9
# proportion_disabled                          9
# proportion_hispanic                          9
# prop_men                                     9
# prop_nonwhite                                9
# prop_nonenglish_speaking                     9
# prop_families_poverty                        9
# prop_students_in_public_school              10
# social_vulnerability_index                   9
# thiel_racial_segregation_index              15
# dtype: int64

# %%
imp_list = [('avg_travel_time_to_work', 'mean'), ('computer_access', 'median'), ('life_expectancy', 'median'), 
 ('median_age', 'mean'), ('median_home_loan_amount', 'median'), ('median_home_value', 'median'), 
 ('median_household_income', 'median'), ('median_leverage_ratio', 'mean'), ('num_jobs', 'mean'), 
 ('num_housing_units', 'mean'), ('proportion_bachelors_degree', 'median'), ('proportion_disabled', 'mean'),
 ('proportion_hispanic', 'median'), ('prop_men', 'mean'), ('prop_nonwhite', 'median'),
('prop_nonenglish_speaking', 'median'), ('prop_families_poverty', 'median'),
('prop_students_in_public_school','median'), ('social_vulnerability_index','mean'),
('thiel_racial_segregation_index', 'mean')]

def impute_val(val):
    if np.isnan(val):
        if IMP_TYPE=='median':
            return fa_pm[COL_NAME].median()
        if IMP_TYPE=='mean':
            return fa_pm[COL_NAME].mean()
    else:
        return val


for COL_NAME, IMP_TYPE in imp_list:
    fa_pm[COL_NAME] = fa_pm[COL_NAME].apply(impute_val)
    
fa_pm.head()
# Out:
#                                       Tract   FIPS State Total Population  \
# 0  Census Tract 1001, Cook County, Illinois  17031    IL            5,563
# 1  Census Tract 1002, Cook County, Illinois  17031    IL            6,872
# 2  Census Tract 1003, Cook County, Illinois  17031    IL            6,186
# 3  Census Tract 1004, Cook County, Illinois  17031    IL            3,364
# 4  Census Tract 1005, Cook County, Illinois  17031    IL            5,696
#
#    2018 Food Insecurity 2018 Food Insecurity #  [C] 2020 Food Insecurity  \
# 0                 0.099                    550                     0.149
# 1                 0.060                    410                     0.110
# 2                 0.074                    460                     0.123
# 3                 0.055                    180                     0.104
# 4                 0.052                    290                     0.101
#
#   [C] 2020 Food Insecurity #  [C] 2020 Food Insecurity # Change  \
# 0                        820                                270
# 1                        750                                340
# 2                        770                                310
# 3                        350                                170
# 4                        570                                280
#
#    [C] Adjusted Annual Unemployment Change  ...  proportion_bachelors_degree  \
# 0                                     0.07  ...                        26.32
# 1                                     0.07  ...                        22.21
# 2                                     0.07  ...                        25.82
# 3                                     0.07  ...                        28.45
# 4                                     0.07  ...                        25.93
#
#    proportion_disabled  proportion_hispanic  prop_men  prop_nonwhite  \
# 0                10.84                16.07     48.30           4.31
# 1                 6.48                11.04     47.22          10.84
# 2                17.10                10.17     44.94          11.75
# 3                 8.98                13.97     51.25           7.52
# 4                12.90                10.45     47.82          12.34
#
#    prop_nonenglish_speaking  prop_families_poverty  \
# 0                     12.54                   6.60
# 1                      5.79                  11.35
# 2                      7.64                   2.00
# 3                      3.97                   0.93
# 4                     14.19                   0.00
#
#    prop_students_in_public_school  social_vulnerability_index  \
# 0                           53.92                        0.36
# 1                           79.56                        0.34
# 2                           68.25                        0.30
# 3                           68.16                        0.27
# 4                           68.67                        0.28
#
#    thiel_racial_segregation_index
# 0                            0.24
# 1                            0.20
# 2                            0.22
# 3                            0.15
# 4                            0.20
#
# [5 rows x 32 columns]

# %%
#check if there are still null values
print(fa_pm.isnull().sum())
# Out:
# Tract                                      0
# FIPS                                       0
# State                                      0
# Total Population                           0
# 2018 Food Insecurity                       0
# 2018 Food Insecurity #                     0
# [C] 2020 Food Insecurity                   0
# [C] 2020 Food Insecurity #                 0
# [C] 2020 Food Insecurity # Change          0
# [C] Adjusted Annual Unemployment Change    0
# local_census_tract                         0
# avg_household_size                         9
# avg_travel_time_to_work                    0
# computer_access                            0
# life_expectancy                            0
# median_age                                 0
# median_home_loan_amount                    0
# median_home_value                          0
# median_household_income                    0
# median_leverage_ratio                      0
# num_jobs                                   0
# num_housing_units                          0
# proportion_bachelors_degree                0
# proportion_disabled                        0
# proportion_hispanic                        0
# prop_men                                   0
# prop_nonwhite                              0
# prop_nonenglish_speaking                   0
# prop_families_poverty                      0
# prop_students_in_public_school             0
# social_vulnerability_index                 0
# thiel_racial_segregation_index             0
# dtype: int64

# %%
fa_pm.to_csv("../Data/Modelling Data/fa_pm-model.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-1543736a1c1a> in <module>
# ----> 1 fa_pm.to_csv("../Data/FA_PM/Modelling Data/fa_pm-model.csv")
#
# C:\Anaconda3\envs\datascience_env\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# C:\Anaconda3\envs\datascience_env\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     182             close = False
#     183         else:
# --> 184             f, handles = get_handle(
#     185                 self.path_or_buf,
#     186                 self.mode,
#
# C:\Anaconda3\envs\datascience_env\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data/FA_PM/Modelling Data/fa_pm-model.csv'
